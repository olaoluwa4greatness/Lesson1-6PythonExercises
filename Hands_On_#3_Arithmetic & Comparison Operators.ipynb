# %%
Basic_Salary = 180000
Performance_Bonus = 45000
Employee_Total_Salary = Basic_Salary + Performance_Bonus
print(Employee_Total_Salary)
# Out:
# 225000

# %%
Total_Salary = 225000
print(Total_Salary >= 220000)
# Out:
# True

# %%
Python = p = 72
SQL = s = 65
Excel = e = 80
Power_BI = b = 75
p + s + e + b
# Out:
# 292

# %%
(p + s + e + b) / 4
# Out:
# 73.0

# %%
((p + s + e + b) / 4) >= 70
# Out:
# True

# %%
Initial_Stock = 250
Sold = 85
Remaining_Stock = Initial_Stock - Sold
print(Remaining_Stock)
# Out:
# 165

# %%
Remaining_Stock = 165
print(Remaining_Stock < 200)
# Out:
# True

# %%
Account_Balance = 520000
Withdraw = 150000
Remaining_Balance = Account_Balance - Withdraw
print(Remaining_Balance)
# Out:
# 370000

# %%
Remaining_Balance = 370000
print(Account_Balance >= Withdraw)
# Out:
# True

# %%
Laptop_Bag = l = 18500
Wireless_Mouse = m = 12000
Keyboard = k = 24500
USB_Drive = u = 5000
print(l + m + k + u)
# Out:
# 60000

# %%
Total = 60000
print(Total >= 50000)
# Out:
# True

# %%
Total = 60000
Discount = 10 / 100
print(Total * Discount)
# Out:
# 6000.0

# %%
Discount_Amount = 6000
Final_Amount = Total - Discount_Amount
print(Final_Amount)
# Out:
# 54000
