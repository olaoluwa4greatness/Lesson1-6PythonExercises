# %%
#Exercise 1 - Customer Registration System

#Variables:
Customer_Name = "Akinyemi Oladele"
Email_Address = "akindele2000@yahoo.com"
Phone_Number = "+2348078982334"
Country = "Nigeria"
Occupation = "Plumber"

#Using F-strings:
Customer_Registration = ( F"Customer name is {Customer_Name}. "
                          F"With email address {Email_Address}. "
                          F"And his phone number is {Phone_Number}. "
                          F"He his a citizen of {Country}. "
                          F"And his occupation is {Occupation}. ")

#Output:
print(Customer_Registration)
# Out:
# Customer name is Akinyemi Oladele. With email address akindele2000@yahoo.com. And his phone number is +2348078982334. He his a citizen of Nigeria. And his occupation is Plumber.

# %%
#Exercise 2 - Hospital Patient Record

#Variables:
Patient_Name = "Mr Ezekiel Sola"
Doctor = "Doctor Babs Davis"
Diagnosis = "Severe Back Pain"
Blood_Group = "O+"
Hospital = "Oyins Care Centre"

#Using F-strings:
Patient_Record = ( F"A particular patient named {Patient_Name}. "
                          F"Was attended to by {Doctor}. "
                          F"And his diagnosis result stated that he has {Diagnosis}. "
                          F"His blood group is {Blood_Group}. "
                          F"And he was diagnosed at {Hospital}. ")

#Output:
print(Patient_Record)
# Out:
# A particular patient named Mr Ezekiel Sola. Was attended to by Doctor Babs Davis. And his diagnosis result stated that he has Severe Back Pain. His blood group is O+. And he was diagnosed at Oyins Care Centre.

# %%
#Exercise 2 - Bonus Challenge - Hospital Patient Record

#Using Mutiline String:
Patient_Record = """A particular patient named Mr Ezekiel Sola.
He was diagnosed by Doctor Babs Davis.
And it was discovered that his suffering from severe back pain.
His blood group was noted has O+.
And he was atteded to at Oyins care centre"""

#Output:
print(Patient_Record)
# Out:
# A particular patient named Mr Ezekiel Sola.
# He was diagnosed by Doctor Babs Davis.
# And it was discovered that his suffering from severe back pain.
# His blood group was noted has O+.
# And he was atteded to at Oyins care centre

# %%
#Exercise 3 - AI Prompt Builder

#Using Multiline String
AI_Model = """You are an AI Assistant.
Analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report."""

#Output:
print(AI_Model)
# Out:
# You are an AI Assistant.
# Analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.

# %%
#Exercise 3 - Bonus Challenge - AI Prompt Builder

#Using Multiline String
AI_Model = """Elijah, you are tasked as an AI Assistant.
To analyze customer feedback.
Identify common complaints.
Provide recommendations.
Generate a summary report.
And execute the prompts using multiline string
And ensure it has concise readility"""

#Output:
print(AI_Model)
# Out:
# Elijah, you are tasked as an AI Assistant.
# To analyze customer feedback.
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
# And execute the prompts using multiline string
# And ensure it has concise readility

# %%
#Case Study Project - Customner Feedback Management System

#Variables:
Customer_Name = "Titilola Abubakar"
Product_Name = "Monitor"
Product_Category = "Computer Accessories"
Customer_Rating = "4 Stars"

#Using Multiline String
Feedback_Report = """Customer Name: Titilola Abubakar
Product: Monitor
Product Category: Computer Accessories
Rating: 4 Stars"""

#Output:
print(Feedback_Report)


#Using Mutiline String
Customer_Review = """

Customer Review

The product ordered arrived as at when stated in the email,
and it was easy to fix with the use of manual.
I enjoy the usage and i rate it 4stars.
I can also refer your e-commerce site with my friends and family"""

#Output:
print(Customer_Review)
# Out:
# Customer Name: Titilola Abubakar
# Product: Monitor
# Product Category: Computer Accessories
# Rating: 4 Stars
#
#
# Customer Review
#
# The product ordered arrived as at when stated in the email,
# and it was easy to fix with the use of manual.
# I enjoy the usage and i rate it 4stars.
# I can also refer your e-commerce site with my friends and family
