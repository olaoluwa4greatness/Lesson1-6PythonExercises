# %%
#Secure Login System - Question 1

#Variables:
username_correct = True
password_correct = True
account_locked = False

#login system rule:
Access_Granted = username_correct and password_correct and not account_locked

#Output:
if Access_Granted:
     print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
#University Scholarship Eligibility - Question 2

#Variables:
score = 85
participated = True
low_income = False

#Scholarship Rule:
qualifies = (score >= 80) and (participated or low_income)

#Output:
if qualifies:
    print("Congratulations!")
    print("Scholarship Approved.")
else:
    print("Scholarship Not Approved.")
# Out:
# Congratulations!
# Scholarship Approved.

# %%
#Smart Server Health Monitor - Question 3

#Variables:
cpu_usage = 75
memory_usage = 92
disk_usage = 60

#Mornitoring System rule:
Critical_Alert = cpu_usage > 90 or memory_usage > 90 or disk_usage > 95
Critical_Alert = False or True or False

#Output:
if Critical_Alert:
    print("Critical Alert")
else:
    print("System Healthy")
# Out:
# Critical Alert

# %%
#Bonus Challenge - Scenerio One

#Variable:
logged_in = True
item_in_stock = True
saved_payment = True
enough_balance = False
account_not_suspended = True

#Customer Order Rule
Order_Confirmed = logged_in and item_in_stock and (saved_payment or enough_balance) and account_not_suspended
Order_Confirmed = True and True and (True or False) and True

#Output:
if Order_Confirmed:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Confirmed

# %%
#Bonus Challenge - Scenerio Two

#Variable:
logged_in = True
item_in_stock = False
saved_payment = True
enough_balance = False
account_not_suspended = True

#Customer Order Rule
Order_Confirmed = logged_in and item_in_stock and (saved_payment or enough_balance) and account_not_suspended
Order_Confirmed = True and False and (True or False) and True

#Output:
if Order_Confirmed:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Failed

# %%
#Bonus Challenge - Scenerio Three

#Variable:
logged_in = False
item_in_stock = True
saved_payment = True
enough_balance = True
account_not_suspended = True

#Customer Order Rule
Order_Confirmed = logged_in and item_in_stock and (saved_payment or enough_balance) and account_not_suspended
Order_Confirmed = False and True and (True or True) and True

#Output:
if Order_Confirmed:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Failed

# %%
#Bonus Challenge - Scenerio Four

#Variable:
logged_in = True
item_in_stock = True
saved_payment = False
enough_balance = False
account_not_suspended = True

#Customer Order Rule
Order_Confirmed = logged_in and item_in_stock and (saved_payment or enough_balance) and account_not_suspended
Order_Confirmed = True and True and (False or False) and True

#Output:
if Order_Confirmed:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Failed

# %%
#Bonus Challenge - Scenerio Five

#Variable:
logged_in = True
item_in_stock = True
saved_payment = False
enough_balance = True
account_not_suspended = True

#Customer Order Rule
Order_Confirmed = logged_in and item_in_stock and (saved_payment or enough_balance) and account_not_suspended
Order_Confirmed = True and True and (False or True) and True

#Output:
if Order_Confirmed:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Confirmed
