# %%
Name = "Olaolu"
Age = 35
Country = "Nigeria"
print("Name:" , Name, "Age:" , Age,  "Country:"  , Country)
# Out:
# Name: Olaolu Age: 35 Country: Nigeria

# %%
Basic_Salary = 180000
Bonus = 30000
Total_Salary = Basic_Salary + Bonus
print(Total_Salary)
# Out:
# 210000

# %%
Name = input("Enter your Name:")
print("Hello", Name)
# Out:
# Enter your Name: Olaolu
# Hello Olaolu

# %%
Fav_Prog_Language = input("Enter the Language:")
print("Hello", Fav_Prog_Language)
# Out:
# Enter the Language: Python
# Hello Python

# %%
x = 50
y = 11.23
name = "Ade"
is_valid = False
print(type(x))
print(type(y))
print(type(name))
print(type(is_valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 45
x = "Hi"
print(type(x))
# Out:
# <class 'str'>

# %%
Name = "Olaolu"
Age = 35
Course = "Python_Programming_Language"
Country = "Nigeria"
print("Name:" , Name)
print("Age:"  , Age)
print("Course:"  , Course)
print("Country:"  , Country)
print(type(Name))
print(type(Age))
print(type(Course))
print(type(Country))
# Out:
# Name: Olaolu
# Age: 35
# Course: Python_Programming_Language
# Country: Nigeria
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
Age = input("Enter your Age:")
print("Age:", Age)
print(type(Age))
Age = 35
print("Age:"  , Age)
print(type(Age))
# Out:
# Enter your Age: 45
# Age: 45
# <class 'str'>
# Age: 35
# <class 'int'>
