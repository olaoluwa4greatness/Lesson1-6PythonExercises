# %%
#Hands-on Exercise 1 - Employee Record Information Extractor (Human Resources)

#Task

#Variable
employee_record = "EMP-HR-2026-004512"

#using string slicing
print(employee_record[0:3])
print(employee_record[4:6])
print(employee_record[7:11])
print(employee_record[12:18])
print(employee_record[0:9])
print(employee_record[12:])
print(employee_record[0:18:2])
print(employee_record[0:18:3])
# Out:
# EMP
# HR
# 2026
# 004512
# EMP-HR-20
# 004512
# EPH-06041
# E--205

# %%
#Hands-on Exercise 2 - Banking Card Security Formatter (Banking & Finance)

#Tank

#Variable
card_number = "5489123476549876"

#using string slicing only

print(card_number[0:4])
print(card_number[12:16])
print(card_number[4:12])
print(card_number[0:16:2])
print(card_number[0:16:3])
print(card_number[18::-1])
print(card_number[7::-1])
# Out:
# 5489
# 9876
# 12347654
# 58137597
# 593696
# 6789456743219845
# 43219845

# %% [markdown]
# ----BONUS CHALLENGE-----

# %%
print(card_number[::-2])
# Out:
# 68464294

# %%
#Hands-on Exercise 3 - Customer information processor (retail analytics)

#task - step 1 & 2

#variable
customer_record = "CUS-LAG-2026-000451"

#using string slicing only
print(customer_record[0:3])
print(customer_record[4:7])
print(customer_record[8:12])
print(customer_record[0:8])
print(customer_record[14:19])
print(customer_record[0:19:2])
print(customer_record[0:19:3])
print(customer_record[19::-1])
# Out:
# CUS
# LAG
# 2026
# CUS-LAG-
# 00451
# CSLG22-041
# C-G0-01
# 154000-6202-GAL-SUC

# %%
#task - step 3

#variable
customer_name = "Christopher Johnson"

#using string slicing
print(customer_name[0:11])
print(customer_name[12:20])
print(customer_name[0:5])
print(customer_name[12::])
print(customer_name[::-1])
# Out:
# Christopher
# Johnson
# Chris
# Johnson
# nosnhoJ rehpotsirhC
