# %%
print("My name is Olaolu")
# Out:
# My name is Olaolu

# %%
print("hello")
# Out:
# hello

# %%
print("hello, world!")
# Out:
# hello, world!

# %%
print("I am learning Python")
# Out:
# I am learning Python

# %%
print("Programming is exciting")
# Out:
# Programming is exciting

# %%
print("My favorite food is Yam")
# Out:
# My favorite food is Yam

# %%
print("My favorite sport is Football")
# Out:
# My favorite sport is Football

# %%
print(15 + 5)
# Out:
# 20

# %%
print(10 // 3)
# Out:
# 3

# %%
print(30 - 12)
# Out:
# 18

# %%
print(9 * 8)
# Out:
# 72

# %%
print(72 / 9)
# Out:
# 8.0

# %%
print("Python")
print("Programming")
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %%
print("My name is Olaolu Ajayi")
# Out:
# My name is Olaolu Ajayi

# %%
print("I want to be a renowed Data Analyst")
# Out:
# I want to be a renowed Data Analyst

# %%
print("The name of my country is Nigeria")
# Out:
# The name of my country is Nigeria

# %%
print(25 + 75)
# Out:
# 100

# %% [raw]
# print(40 // 6)

# %%
print(8 * 2)
# Out:
# 16

# %%
print("powerbi")
print("MsExcel")
print("Programming")
# Out:
# powerbi
# MsExcel
# Programming

# %% [markdown]
# programming language

# %%
message = "Hello, World!"
print(message)
# Out:
# Hello, World!

# %%
a = 5
b = 4
result = a + b
print(result)
# Out:
# 9

# %%
length = len ("Python")
print(length)
# Out:
# 6

# %%
name = input("Enter your name:")
print("Hello", name)
# Out:
# Enter your name: Olaolu
# Hello Olaolu

# %%
x = 10
y = 3.14
name = "Ola"
is_valid = True
print(type(x))
print(type(y))
print(type(name))
print(type(is_valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 10
x = "Hello"
print(type(x))
# Out:
# <class 'str'>

# %%
name = "Ola"
age = 35
print("Name:" , name, "Age:" , age)
# Out:
# Name: Ola Age: 35

# %%
x = 10
print(x == 10)
print(x == 20)
# Out:
# True
# False

# %%
x = y = z = 10
result = x + y +z
print(result)
# Out:
# 30

# %%
x = y = 20
y = 30
print(x), print(y)
print(x)
print(y)
# Out:
# 20
# 30
# 20
# 30
